# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("share-of-individuals-using-the-internet.csv")

# %%
df.rename(columns={'Entity': 'Country', 'Code': 'Courntry_Code', 'Individuals using the Internet (% of population)': '% of Population Interntet Users'}, inplace=True)

# %%
df
# Out:
#           Country Courntry_Code  Year  % of Population Interntet Users
# 0     Afghanistan           AFG  1990                         0.000000
# 1     Afghanistan           AFG  1991                         0.000000
# 2     Afghanistan           AFG  1992                         0.000000
# 3     Afghanistan           AFG  1993                         0.000000
# 4     Afghanistan           AFG  1994                         0.000000
# ...           ...           ...   ...                              ...
# 6528     Zimbabwe           ZWE  2016                        23.119989
# 6529     Zimbabwe           ZWE  2017                        24.400000
# 6530     Zimbabwe           ZWE  2018                        25.000000
# 6531     Zimbabwe           ZWE  2019                        25.100000
# 6532     Zimbabwe           ZWE  2020                        29.299999
#
# [6533 rows x 4 columns]

# %%
df_china = df[df['Country'] == 'China']
plt.plot(df_china['Year'], df_china['% of Population Interntet Users'], color='#E95C16', linewidth=2, marker='o', dashes=[.35])

df_country = df[df['Country'] == 'United States']
plt.plot(df_country['Year'], df_country['% of Population Interntet Users'], color='#16A3E9', linewidth=2, marker='o')

plt.xlabel('Year', fontname='CND Light', fontsize=12)
plt.ylabel('% of Population Internet Users', fontname='CND Light', fontsize=12)
#plt.title('Internet Usage over the years in the USA', fontname='CND Medium', fontsize=14)
plt.text(0.5, .92, "This chart shows the internet adoption in the USA", ha='right', va='center', fontsize=8, transform=plt.gcf().transFigure)

plt.suptitle('Internet Usage over the years in the USA', fontname='CND Medium', fontsize=14, ha='right', va='top', x=0.69)

plt.gca().set_facecolor('#E9EDF0')
plt.gcf().set_facecolor('#E9EDF0')

plt.axvspan(2012, 2016, color='#FFA39F', alpha=0.3)
plt.text(2014, 65, "4G Adoption", ha='center', va='center', fontsize=8, color='black')

plt.gca().yaxis.grid(True, color='#B7C6CF')
plt.gca().xaxis.grid(False)

plt.ylim(0, 100)



plt.tight_layout()
plt.show()

# %%
df_country = df[df['Country'] == 'United States']
plt.plot(df_country['Year'], df_country['% of Population Interntet Users'], color='#0092A7', linewidth=2)

plt.xlabel('Year', fontname='CND Light', fontsize=12)
plt.ylabel('% of Population Internet Users', fontname='CND Light', fontsize=12)
plt.title('Internet Usage over the years in the USA', fontname='CND Medium', fontsize=14)

plt.gca().set_facecolor('#E9EDF0')
plt.gcf().set_facecolor('#E9EDF0')

plt.axvspan(2012, 2016, color='#FFA39F', alpha=0.3)
plt.text(2014, 65, "4G Adoption", ha='center', va='center', fontsize=8, color='black')

plt.gca().yaxis.grid(True, color='#B7C6CF')
plt.gca().xaxis.grid(False)

plt.ylim(0, 100)

plt.tight_layout()
plt.show()

# %%
df_china = df[df['Country'] == 'China']
plt.plot(df_china['Year'], df_china['% of Population Interntet Users'], color='#0092A7', linewidth=2)

df_country = df[df['Country'] == 'United States']
plt.plot(df_country['Year'], df_country['% of Population Interntet Users'], color='#0092A7', linewidth=2)

plt.xlabel('Year', fontname='CND Light', fontsize=12)
plt.ylabel('% of Population Internet Users', fontname='CND Light', fontsize=12)
plt.title('Internet Usage over the years in the USA', fontname='CND Medium', fontsize=14)

plt.gca().set_facecolor('#E9EDF0')
plt.gcf().set_facecolor('#E9EDF0')

plt.axvspan(2012, 2016, color='#FFA39F', alpha=0.3)
plt.text(2014, 65, "4G Adoption", ha='center', va='center', fontsize=8, color='black')

plt.gca().yaxis.grid(True, color='#B7C6CF')
plt.gca().xaxis.grid(False)

plt.ylim(0, 100)

plt.tight_layout()
plt.show()
